# %%
import csv
import json
import os
import pprint

import pandas as pd
import requests

# %%
auth_token = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI2YTE0OGZkMi1jMTY3LTRhMDYtODBhZC0xMzI5ODIyNmM1OWUiLCJleHAiOjE2Nzc4MDAwMjgsInJvbGUiOiJBRE1JTiJ9.MHA4oyKs8uaS_chkRPV7DwHTGE-n-_5sUF6BN17zEtI"

# %%
headers = {'Authorization': f"Bearer {auth_token}"}

# %%
url = 'http://localhost:8080/graphql'

# %%
# Add a JSON query
query = """
query {
 personByName(name:"em") {
  	givenName
  postalCode
  city
	}
}
"""

# %%
r = requests.post(url=url, json={'query': query}, headers=headers)

# %%
data = r.json()
data
# Out:
# {'data': {'personByName': [{'givenName': 'Emily',
#     'postalCode': 'M5V 3L7',
#     'city': 'Toronto'},
#    {'givenName': 'Jeremy', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Jeremy', 'postalCode': 'R3C 4W1', 'city': 'Winnipeg'},
#    {'givenName': 'Emily', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Jeremy', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Emily', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Emily', 'postalCode': 'M5V 3L7', 'city': 'Toronto'},
#    {'givenName': 'Emily', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Jeremiah', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Jeremy', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Emily', 'postalCode': 'M5V 3L7', 'city': 'Toronto'},
#    {'givenName': 'Madison', 'postalCode': 'R3C 4W1', 'city': 'Winnipeg'},
#    {'givenName': 'Jeremy', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Emily', 'postalCode': 'R3C 4W1', 'city': 'Winnipeg'},
#    {'givenName': 'Michael', 'postalCode': 'R3C 4W1', 'city': 'Winnipeg'},
#    {'givenName': 'Emily', 'postalCode': 'M5V 3L7', 'city': 'Toronto'},
#    {'givenName': 'Jeremy', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Jeremy', 'postalCode': 'M5V 3L7', 'city': 'Toronto'},
#    {'givenName': 'Jeremiah', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Jeremy', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Stacy', 'postalCode': 'R3C 4W1', 'city': 'Winnipeg'},
#    {'givenName': 'Jeremy', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Jeremy', 'postalCode': 'M5V 3L7', 'city': 'Toronto'},
#    {'givenName': 'Chelsey', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Emma', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Emily', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Emily', 'postalCode': 'K2E 7J5', 'city': 'Ottawa'},
#    {'givenName': 'Jeremy', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Emily', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Samantha', 'postalCode': 'H2Z 1X4', 'city': 'Montreal'},
#    {'givenName': 'Jeremy', 'postalCode': 'M5V 3L7', 'city': 'Toronto'}]}}

# %%
df = pd.json_normalize(data['data']['personByName'])

# %%
df
# Out:
#    givenName postalCode      city
# 0      Emily    M5V 3L7   Toronto
# 1     Jeremy    H2Z 1X4  Montreal
# 2     Jeremy    R3C 4W1  Winnipeg
# 3      Emily    H2Z 1X4  Montreal
# 4     Jeremy    K2E 7J5    Ottawa
# 5      Emily    H2Z 1X4  Montreal
# 6      Emily    M5V 3L7   Toronto
# 7      Emily    H2Z 1X4  Montreal
# 8   Jeremiah    H2Z 1X4  Montreal
# 9     Jeremy    K2E 7J5    Ottawa
# 10     Emily    M5V 3L7   Toronto
# 11   Madison    R3C 4W1  Winnipeg
# 12    Jeremy    K2E 7J5    Ottawa
# 13     Emily    R3C 4W1  Winnipeg
# 14   Michael    R3C 4W1  Winnipeg
# 15     Emily    M5V 3L7   Toronto
# 16    Jeremy    H2Z 1X4  Montreal
# 17    Jeremy    M5V 3L7   Toronto
# 18  Jeremiah    K2E 7J5    Ottawa
# 19    Jeremy    K2E 7J5    Ottawa
# 20     Stacy    R3C 4W1  Winnipeg
# 21    Jeremy    H2Z 1X4  Montreal
# 22    Jeremy    M5V 3L7   Toronto
# 23   Chelsey    K2E 7J5    Ottawa
# 24      Emma    H2Z 1X4  Montreal
# 25     Emily    K2E 7J5    Ottawa
# 26     Emily    K2E 7J5    Ottawa
# 27    Jeremy    H2Z 1X4  Montreal
# 28     Emily    H2Z 1X4  Montreal
# 29  Samantha    H2Z 1X4  Montreal
# 30    Jeremy    M5V 3L7   Toronto
